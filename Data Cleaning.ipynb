# %%
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# <h4>Importing data from excel file</h4>

# %%
file = pd.read_excel('Crop production data.xlsx')
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %% [markdown]
# <h4>Identifying and Removing outliers from dataset using Z-score method</h4>

# %%
 file['Z-score'] = np.abs(stats.zscore(file['Area']))
# outliers = file[file['Z-score']>3]
file_wol = file[file['Z-score']<=3]
file_wol = file_wol.drop('Z-score', axis=1)

# %% [markdown]
# <h4>Which columns contain null values and how much?</h4>

# %%
file_wol.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3722
# dtype: int64

# %%
file_wol['Production per area'] = file_wol['Production'].where(file_wol['Production'].notna(), None)/file_wol['Area']
file_wol.isnull().sum()
# Out:
# State_Name                0
# District_Name             0
# Crop_Year                 0
# Season                    0
# Crop                      0
# Area                      0
# Production             3722
# Production per area    3722
# dtype: int64

# %% [markdown]
# <h4>Dealing with null values</h4>

# %%
grouped_mean1 = file_wol.groupby(['State_Name', 'District_Name', 'Crop', 'Season'])['Production per area'].transform('mean')
file_wol['Production per area'] = file_wol['Production per area'].fillna(grouped_mean1)

# %%
file_wol.isnull().sum()
# Out:
# State_Name                0
# District_Name             0
# Crop_Year                 0
# Season                    0
# Crop                      0
# Area                      0
# Production             3722
# Production per area     603
# dtype: int64

# %%
file_wol = file_wol.dropna(subset=['Production per area'])

# %%
file_wol.isnull().sum()
# Out:
# State_Name                0
# District_Name             0
# Crop_Year                 0
# Season                    0
# Crop                      0
# Area                      0
# Production             3119
# Production per area       0
# dtype: int64

# %%
file_wol.loc[:, 'Production'] = file['Production'].fillna(file_wol['Production per area'] * file_wol['Area'])

# %%
file_wol.isnull().sum()
# Out:
# State_Name             0
# District_Name          0
# Crop_Year              0
# Season                 0
# Crop                   0
# Area                   0
# Production             0
# Production per area    0
# dtype: int64

# %%
file_wol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 241943 entries, 0 to 246090
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   State_Name           241943 non-null  object
#  1   District_Name        241943 non-null  object
#  2   Crop_Year            241943 non-null  int64
#  3   Season               241943 non-null  object
#  4   Crop                 241943 non-null  object
#  5   Area                 241943 non-null  float64
#  6   Production           241943 non-null  float64
#  7   Production per area  241943 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 24.7+ MB

# %% [markdown]
# <h4>Dividing the dataset into 4 separate parts</h4>

# %%
file1 = file_wol.loc[(file_wol['Crop_Year'] >= 1997) & (file_wol['Crop_Year'] <= 2000)]
file1
# Out:
#                  State_Name    District_Name  Crop_Year       Season  \
# 0       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 1       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 2       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Kharif
# 3       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Whole Year
# 4       ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2000  Whole Year
# ...                     ...              ...        ...          ...
# 245578          West Bengal         PURULIYA       2000  Whole Year
# 245579          West Bengal         PURULIYA       2000  Whole Year
# 245580          West Bengal         PURULIYA       2000  Whole Year
# 245581          West Bengal         PURULIYA       2000  Whole Year
# 245582          West Bengal         PURULIYA       2000  Whole Year
#
#                        Crop    Area  Production  Production per area
# 0                  Arecanut  1254.0      2000.0             1.594896
# 1       Other Kharif pulses     2.0         1.0             0.500000
# 2                      Rice   102.0       321.0             3.147059
# 3                    Banana   176.0       641.0             3.642045
# 4                 Cashewnut   720.0       165.0             0.229167
# ...                     ...     ...         ...                  ...
# 245578               Potato   866.0     12758.0            14.732102
# 245579             Sannhamp   105.0       252.0             2.400000
# 245580              Sesamum   498.0       193.0             0.387550
# 245581            Sugarcane   588.0     42310.0            71.955782
# 245582             Turmeric   171.0        64.0             0.374269
#
# [45745 rows x 8 columns]

# %%
file2 = file_wol.loc[(file_wol['Crop_Year'] >= 2001) & (file_wol['Crop_Year'] <= 2004)]
file2
# Out:
#                  State_Name    District_Name  Crop_Year       Season  \
# 10      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2001  Kharif
# 11      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2001  Kharif
# 12      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2001  Kharif
# 13      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2001  Whole Year
# 14      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2001  Whole Year
# ...                     ...              ...        ...          ...
# 245723          West Bengal         PURULIYA       2004  Whole Year
# 245724          West Bengal         PURULIYA       2004  Whole Year
# 245725          West Bengal         PURULIYA       2004  Whole Year
# 245726          West Bengal         PURULIYA       2004  Whole Year
# 245727          West Bengal         PURULIYA       2004  Whole Year
#
#                        Crop     Area  Production  Production per area
# 10                 Arecanut   1254.0      2061.0             1.643541
# 11      Other Kharif pulses      2.0         1.0             0.500000
# 12                     Rice     83.0       300.0             3.614458
# 13                Cashewnut    719.0       192.0             0.267038
# 14                 Coconut   18190.0  64430000.0          3542.056075
# ...                     ...      ...         ...                  ...
# 245723             Sannhamp    211.0       874.0             4.142180
# 245724              Sesamum    771.0       298.0             0.386511
# 245725            Sugarcane    722.0     33391.0            46.247922
# 245726              Tobacco      8.0         1.0             0.125000
# 245727             Turmeric    270.0       166.0             0.614815
#
# [60603 rows x 8 columns]

# %%
file3 = file_wol.loc[(file_wol['Crop_Year'] >= 2005) & (file_wol['Crop_Year'] <= 2009)]
file3
# Out:
#                  State_Name    District_Name  Crop_Year       Season  \
# 45      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2005  Kharif
# 46      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2005  Whole Year
# 47      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2005  Whole Year
# 48      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2005  Whole Year
# 49      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2005  Whole Year
# ...                     ...              ...        ...          ...
# 245917          West Bengal         PURULIYA       2009  Summer
# 245918          West Bengal         PURULIYA       2009  Summer
# 245919          West Bengal         PURULIYA       2009  Whole Year
# 245920          West Bengal         PURULIYA       2009  Whole Year
# 245922          West Bengal         PURULIYA       2009  Winter
#
#                 Crop    Area    Production  Production per area
# 45              Rice    2.09     12.060000             5.770335
# 46          Arecanut  795.67    802.708281             1.008846
# 47            Banana   22.00    582.000000            26.454545
# 48      Black pepper   41.00      0.100000             0.002439
# 49         Cashewnut  450.00     55.800000             0.124000
# ...              ...     ...           ...                  ...
# 245917          Rice  374.00    795.000000             2.125668
# 245918       Sesamum   15.00     11.000000             0.733333
# 245919     Sugarcane  304.00  25261.000000            83.095395
# 245920       Tobacco   10.00      3.000000             0.300000
# 245922       Sesamum  238.00     87.000000             0.365546
#
# [70099 rows x 8 columns]

# %%
file4 = file_wol.loc[(file_wol['Crop_Year'] >= 2010) & (file_wol['Crop_Year'] <= 2015)]
file4
# Out:
#                  State_Name    District_Name  Crop_Year       Season  \
# 64      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2010  Autumn
# 65      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2010  Autumn
# 66      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2010  Rabi
# 67      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2010  Rabi
# 68      ANDAMAN AND NICOBAR  NICOBAR ISLANDS       2010  Rabi
# ...                     ...              ...        ...          ...
# 246085          West Bengal         PURULIYA       2014  Summer
# 246086          West Bengal         PURULIYA       2014  Summer
# 246087          West Bengal         PURULIYA       2014  Summer
# 246088          West Bengal         PURULIYA       2014  Whole Year
# 246090          West Bengal         PURULIYA       2014  Winter
#
#                 Crop    Area  Production  Production per area
# 64              Rice     3.5       10.00             2.857143
# 65         Sugarcane    13.4       41.75             3.115672
# 66          Arecanut   944.0     1610.00             1.705508
# 67      Black pepper    23.0        8.50             0.369565
# 68         Cashewnut  1000.5      260.50             0.260370
# ...              ...     ...         ...                  ...
# 246085         Maize   325.0     2039.00             6.273846
# 246086          Rice   306.0      801.00             2.617647
# 246087       Sesamum   627.0      463.00             0.738437
# 246088     Sugarcane   324.0    16250.00            50.154321
# 246090       Sesamum   175.0       88.00             0.502857
#
# [65496 rows x 8 columns]

# %% [markdown]
# <h4>Exporting each file to CSV format</h4>

# %%
file1.to_csv('Crop_production_data_1997-2000.csv', index=False, header=True)
file2.to_csv('Crop_production_data_2001-2005.csv', index=False, header=True)
file3.to_csv('Crop_production_data_2006-2010.csv', index=False, header=True)
file4.to_csv('Crop_production_data_2011-2015.csv', index=False, header=True)
